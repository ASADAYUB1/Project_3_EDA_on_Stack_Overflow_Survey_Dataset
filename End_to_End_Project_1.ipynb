# %%
import numpy as np 

import pandas as pd 

import matplotlib

import matplotlib.pyplot as plt

import seaborn as sns 
# %matplotlib inline

# %%
survey_raw_df = pd.read_csv('survey_results_public_2020.csv')

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
survey_raw_df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
survey_raw_df.shape
# Out:
# (64461, 61)

# %%
survey_raw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
schema_raw = pd.read_csv('survey_results_schema.csv',index_col='qname').question
schema_raw
# Out:
# qname
# S0             <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                       Browser Meta Info
# Q310           <div><span style="font-size:19px;"><strong>You...
# Q120
# S1             <span style="font-size:22px; font-family: aria...
#                                      ...
# Knowledge_7    Waiting on answers to questions often causes i...
# Knowledge_8    I feel like I have the tools and/or resources ...
# Frequency_1    Needing help from people outside of your immed...
# Frequency_2    Interacting with people outside of your immedi...
# Frequency_3    Encountering knowledge silos (where one indivi...
# Name: question, Length: 78, dtype: object

# %% [markdown]
# # Data Preparation & Cleaning

# %% [markdown]
# Demographics of the survey respondents and the global programming community
#
# Distribution of programming skills, experience, and preferences
#
# Employment-related information, preferences, and opinions

# %%
selected_columns = ['Country' , 'Age', 'Gender', 'EdLevel', 'UndergradMajor', 
                   'Hobbyist', 'Age1stCode', 'YearsCode', 'YearsCodePro','LanguageWorkedWith','LanguageDesireNextYear','NEWLearn','NEWStuck',
                   'Employment','DevType','WorkWeekHrs','JobSat','JobFactors','NEWOvertime','NEWEdImpt']

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_df = survey_raw_df[selected_columns].copy()
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.shape
# Out:
# (64461, 20)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
survey_df.describe()
# Out:
#                 Age   WorkWeekHrs
# count  45446.000000  41151.000000
# mean      30.834111     40.782174
# std        9.585392     17.816383
# min        1.000000      1.000000
# 25%       24.000000     40.000000
# 50%       29.000000     40.000000
# 75%       35.000000     44.000000
# max      279.000000    475.000000

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df.drop(survey_df[survey_df.Age < 10].index, inplace = True)
survey_df.drop(survey_df[survey_df.Age > 100].index, inplace = True)

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140 ].index, inplace = True)

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df['Gender'].value_counts()
# Out:
# Gender
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
survey_df.where(~(survey_df.Gender.str.contains(';' , na=False)),np.nan, inplace = True)

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.sample(10)
# Out:
#               Country   Age Gender  \
# 29229         Germany  17.0    Man
# 11026         Germany  37.0    Man
# 35323          Canada   NaN    NaN
# 49989   United States  40.0    Man
# 22826  United Kingdom  33.0    Man
# 9719           France  25.0    Man
# 35931   United States  66.0    Man
# 58249           India  22.0    Man
# 41549         Germany   NaN    NaN
# 6970    United States  50.0    Man
#
#                                                  EdLevel  \
# 29229  Secondary school (e.g. American high school, G...
# 11026       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35323                                                NaN
# 49989    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22826    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9719     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 35931       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58249       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
sns.set_style("whitegrid")
matplotlib.rcParams['font.size'] = 18
matplotlib.rcParams['figure.figsize'] = (12,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# Let's look at the number of countries from which there are responses in the survey and plot the ten countries with the highest number of responses.

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
higher_response_countries = survey_df.Country.value_counts().head(12)
higher_response_countries
# Out:
# Country
# United States     12371
# India              8364
# United Kingdom     3881
# Germany            3864
# Canada             2175
# France             1884
# Brazil             1804
# Netherlands        1332
# Poland             1259
# Australia          1199
# Spain              1157
# Italy              1115
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=75)
plt.title('Different_Countries_Responses' )
sns.barplot(x=higher_response_countries.index, y=higher_response_countries);

# %%
countries_languages_df = pd.read_csv('countries_languages.csv')

# %%
countries_languages_df
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                            Andorra
# 4                             Angola
# ..                               ...
# 193                          Vietnam
# 194  Western Sahara (proposed state)
# 195                            Yemen
# 196                           Zambia
# 197                         Zimbabwe
#
#                                       Languages_Spoken
# 0    Dari Persian, Pashtu (both official), other Tu...
# 1       Albanian (Tosk is the official dialect), Greek
# 2           Arabic (official), French, Berber dialects
# 3    Catalán (official), French, Castilian, Portuguese
# 4    Portuguese (official), Bantu and other African...
# ..                                                 ...
# 193  Vietnamese (official); English (increasingly f...
# 194                  Hassaniya Arabic, Moroccan Arabic
# ...

# %%
countries_languages_df['English'] = countries_languages_df['Languages_Spoken'].str.contains('English')

# %%
countries_languages_df['LanguagePreferred'] = countries_languages_df['English'].map({True:'English', False:'NonEnglish'})
countries_languages_df
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                            Andorra
# 4                             Angola
# ..                               ...
# 193                          Vietnam
# 194  Western Sahara (proposed state)
# 195                            Yemen
# 196                           Zambia
# 197                         Zimbabwe
#
#                                       Languages_Spoken  English  \
# 0    Dari Persian, Pashtu (both official), other Tu...    False
# 1       Albanian (Tosk is the official dialect), Greek    False
# 2           Arabic (official), French, Berber dialects    False
# 3    Catalán (official), French, Castilian, Portuguese    False
# 4    Portuguese (official), Bantu and other African...    False
# ..                                                 ...      ...
# ...

# %%
combined_df = pd.merge(survey_df, countries_languages_df, on='Country')
combined_df
# Out:
#                 Country   Age Gender  \
# 0               Germany   NaN    Man
# 1               Germany   NaN    Man
# 2               Germany  27.0    Man
# 3               Germany  45.0    Man
# 4               Germany  29.0    Man
# ...                 ...   ...    ...
# 61479   Solomon Islands  25.0    Man
# 61480        Cape Verde   NaN    NaN
# 61481        Cape Verde  35.0    Man
# 61482             Gabon   NaN    NaN
# 61483  Marshall Islands   NaN    NaN
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1      Secondary school (e.g. American high school, G...
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                     Professional degree (JD, MD, etc.)
# 4        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                  ...
# 61479  Secondary school (e.g. American high school, G...
# ...

# %%
lang_Per = combined_df.LanguagePreferred.value_counts()
lang_Per
# Out:
# LanguagePreferred
# English       38645
# NonEnglish    22839
# Name: count, dtype: int64

# %%
lang_Per = lang_Per/combined_df.shape[0] * 100
lang_Per
# Out:
# LanguagePreferred
# English       62.853751
# NonEnglish    37.146249
# Name: count, dtype: float64

# %%
fig = plt.figure(figsize =(12, 8))
plt.title('English Speaking Vs Non-English Speaking Countries in the Survey')
plt.pie(lang_Per, labels = lang_Per.index, autopct = '%1.1f%%', startangle = 240);

# %%
plt.figure(figsize=(12,8))
plt.title('Your Age is  (In Years)')
plt.xlabel('Age')
plt.ylabel('Number of Respondents')

plt.hist(survey_df.Age, bins =np.arange(10,80,6), color = 'red');

# %%
survey_df['AgeGroup'] = pd.cut(x=survey_df['Age'], bins=[0,10,18,30,45,60,100], labels=['Younger than 10 years', '10-18 years', '18-30 years', '30-45 years', '45-60 years', 'Older than 60 years'])
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
c = survey_df.AgeGroup.value_counts()
sns.barplot(x=c.index, y=c)
# Out:
# <Axes: xlabel='AgeGroup', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=65)
plt.title("Age Group of Respondent's People")

sns.barplot(x = c.index, y= c, color = 'steelblue');

# %%
Gender_count = survey_df.Gender.value_counts()
Gender_count
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title("Respondent's Gender")

plt.pie(Gender_count, labels= Gender_count.index, autopct= '%1.1f%%', startangle=360 );

# %%
plt.figure(figsize=(20,20))
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.title("Respondens's Highest Education Level")
plt.ylabel(None);

# %% [markdown]
# Primary Feild of Study

# %%
undergrad_pct = survey_df.UndergradMajor.value_counts()*100/survey_df.UndergradMajor.count()
undergrad_pct
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   61.939193
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       9.354195
# Information systems, information technology, or system administration              7.983168
# A natural science (such as biology, chemistry, physics, etc.)                      4.316561
# Mathematics or statistics                                                          3.627097
# Web development or web design                                                      3.502637
# A business discipline (such as accounting, finance, marketing, etc.)               2.700567
# A humanities discipline (such as literature, history, philosophy, etc.)            1.969616
# A social science (such as anthropology, psychology, political science, etc.)       1.821450
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     1.412513
# ...

# %%
plt.figure(figsize=(25,19))
sns.barplot(x=undergrad_pct, y=undergrad_pct.index);

plt.title('Primary Field of Study')
plt.ylabel(None)
plt.xlabel('Percentage');

# %%
survey_df['Degree'] = (survey_df.UndergradMajor== 'Computer science, computer engineering, or software engineering')

# %%
survey_df['CompDeg'] = survey_df['Degree'].map({True:'Computer Science', False: 'Not Computer Science'})
survey_df.CompDeg.value_counts()
# Out:
# CompDeg
# Not Computer Science    32953
# Computer Science        31353
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
plt.title("Respondent Degree")
plt.pie(survey_df.CompDeg.value_counts(), labels= survey_df.CompDeg.value_counts().index, autopct= '%1.1f%%', startangle=90 );

# %%
edimp_count= survey_df['NEWEdImpt'].value_counts()
edimp_count
# Out:
# NEWEdImpt
# Fairly important                      12588
# Very important                        11783
# Somewhat important                    11298
# Not at all important/not necessary     7707
# Critically important                   4716
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(y=survey_df.NEWEdImpt,hue = survey_df.CompDeg )
plt.title('Importance of Computer Degree in Career')
plt.ylabel(None);

# %% [markdown]
# Your Current Employment Status

# %%
survey_df.Employment.value_counts()
# Out:
# Employment
# Employed full-time                                      44958
# Student                                                  7734
# Independent contractor, freelancer, or self-employed     5619
# Not employed, but looking for work                       2324
# Employed part-time                                       2200
# Not employed, and not looking for work                    318
# Retired                                                   241
# Name: count, dtype: int64

# %%
survey_df.Employment.value_counts(normalize=True, ascending=True)
# Out:
# Employment
# Retired                                                 0.003802
# Not employed, and not looking for work                  0.005016
# Employed part-time                                      0.034704
# Not employed, but looking for work                      0.036660
# Independent contractor, freelancer, or self-employed    0.088636
# Student                                                 0.121999
# Employed full-time                                      0.709184
# Name: proportion, dtype: float64

# %%
(survey_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='c')
plt.title("Employment Status of Respondents")
plt.xlabel('Percentage');
plt.ylabel(None);

# %% [markdown]
# Which Describe You

# %%
survey_df.DevType.value_counts()
# Out:
# DevType
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
# ...

# %% [markdown]
# Let's define a helper function that turns a column containing lists of values (like survey_df.DevType) into a data frame with one column for each possible option.

# %%
col_series = survey_df.DevType
result_df = col_series.to_frame()
for idx, value in col_series[col_series.notnull()].items():
        
        #breake each option into list of options
    for option in value.split(';'):
            
            # Add the option as a column to result
        if not option in result_df.columns:
                
            options.append(option)
            result_df[option] = False
                # Mark the value in the option column as True
            result_df.at[idx, option] = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 11
#       6 for option in value.split(';'):
#       7
#       8         # Add the option as a column to result
#       9     if not option in result_df.columns:
# ---> 11         options.append(option)
#      12         result_df[option] = False
#      13             # Mark the value in the option column as True
#
# NameError: name 'options' is not defined

# %%
 result_df

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].items():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
dev_type_df = split_multicolumn(survey_df.DevType)

# %%
dev_type_df

# %%
dev_type_totals = dev_type_df.sum().sort_values(ascending=False)
dev_type_totals

# %%
survey_df.LanguageWorkedWith

# %%
languages_worked_df = split_multicolumn(survey_df.LanguageWorkedWith)

# %%
languages_worked_df

# %%
languages_worked_percentages = languages_worked_df.mean().sort_values(ascending=False) * 100
languages_worked_percentages

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index)
plt.title("Languages used in the past year");
plt.xlabel('count');

# %%
languages_interested_df = split_multicolumn(survey_df.LanguageDesireNextYear)
languages_interested_percentages = languages_interested_df.mean().sort_values(ascending=False) * 100
languages_interested_percentages

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_interested_percentages, y=languages_interested_percentages.index)
plt.title("Languages people are intersted in learning over the next year");
plt.xlabel('count');

# %%
languages_loved_df = languages_worked_df & languages_interested_df

# %%
languages_loved_percentages = (languages_loved_df.sum() * 100/ languages_worked_df.sum()).sort_values(ascending=False)

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_loved_percentages, y=languages_loved_percentages.index)
plt.title("Most loved languages");
plt.xlabel('count');

# %%
countries_df = survey_df.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs', ascending=False)

# %%
high_response_countries_df = countries_df.loc[survey_df.Country.value_counts() > 250].head(15)

# %%
high_response_countries_df

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=survey_df)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %%
plt.title('Age When Write First Program')
sns.histplot(x=survey_df.Age1stCode, bins=30, kde=True);
